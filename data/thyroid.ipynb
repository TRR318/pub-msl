# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from skpsl import ProbabilisticScoringList

# %%
df= pd.read_csv("data/thyroid+disease/ann-train.data", sep=" ", header=None)

# %%
df = df[df[21].isin([2,3])]

psl = ProbabilisticScoringList(set(range(-3,3))-{0})
psl.fit(df.iloc[:,:20], df[21])
# Out:
# ProbabilisticScoringList(score_set={1, 2, -2, -3, -1})

# %%
psl.inspect()
# Out:
#     Stage  Feature Index  Score   T = -19   T = -18   T = -17   T = -16  \
# 0       0            NaN    NaN       NaN       NaN       NaN       NaN
# 1       1            2.0    2.0       NaN       NaN       NaN       NaN
# 2       2            9.0   -1.0       NaN       NaN       NaN       NaN
# 3       3            6.0    2.0       NaN       NaN       NaN       NaN
# 4       4            7.0    2.0       NaN       NaN       NaN       NaN
# 5       5            1.0    1.0       NaN       NaN       NaN       NaN
# 6       6           12.0    2.0       NaN       NaN       NaN       NaN
# 7       7            4.0    1.0       NaN       NaN       NaN       NaN
# 8       8            3.0   -1.0       NaN       NaN       NaN       NaN
# 9       9           14.0    2.0       NaN       NaN       NaN       NaN
# 10     10           11.0    1.0       NaN       NaN       NaN       NaN
# 11     11           16.0   -3.0       NaN       NaN       NaN       NaN
# ...

# %%
plt.scatter(df[16], df[21])
plt.xscale('log')
